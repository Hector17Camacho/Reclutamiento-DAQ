# %% [markdown]
# # Diagnóstico de Telemetría – Fórmula SAE
#
# Este notebook carga `datos/data.csv`, valida su calidad, filtra señales con fase cero y genera hallazgos de seguridad.
#
# **Nota:** completar con evidencia real en `resultados/` (AGREGAR_RESULTADOS_EXPERIMENTALES).

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(ROOT / 'src'))

from telemetria import run_analysis

# %%
input_csv = ROOT / 'datos' / 'data.csv'
output_dir = ROOT / 'resultados'

results = run_analysis(input_csv=input_csv, output_dir=output_dir)
results

# %% [markdown]
# ## Pendientes de entrega
#
# - AGREGAR_RESULTADOS_EXPERIMENTALES en `resultados/reporte_tecnico.md`
# - Reemplazar imágenes de resultados por salidas reales del análisis
# - Completar interpretación del diagrama G-G con datos del ensayo
